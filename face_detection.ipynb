# %%
import cv2
from ultralytics import YOLO

# %% [markdown]
# ### 1_reading image and show it using cv2

# %%
img_path = "./images/dog.jpg"
img = cv2.imread(img_path)
cv2.imshow("window1", img)
cv2.moveWindow("window1",0, 0)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %% [markdown]
# ### 2_loading model and process image

# %%
model = YOLO("yolov8n.pt")
# Out:
# 0: 384x640 1 airplane, 84.0ms
# Speed: 2.4ms preprocess, 84.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# list

# %%
result = model(img)
cv2.imshow("window1", result[0].plot())
cv2.moveWindow("window1", 0, 0)
cv2.waitKey(10000)
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 bicycle, 1 car, 1 truck, 1 dog, 118.9ms
# Speed: 2.7ms preprocess, 118.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# ### 3_load comunity version of face detection

# %%
face_model = YOLO("face_detection_models/yolov12m-face.pt")

# %%
face_detection_result = face_model(img)
cv2.imshow("window1", face_detection_result[0].plot())
cv2.moveWindow("window1", 0, 0)
cv2.waitKey(10000)
cv2.destroyAllWindows()
# Out:
# 0: 480x640 2 faces, 450.4ms
# Speed: 3.8ms preprocess, 450.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
