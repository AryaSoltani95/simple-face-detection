# %%
import cv2
from ultralytics import YOLO

# %% [markdown]
# ### 1_reading image and show it using cv2

# %%
img_path = "./images/drone.jpg"
img = cv2.imread(img_path)
cv2.imshow("window1", img)
cv2.moveWindow("window1",300, 300)
cv2.waitKey(10000)
cv2.destroyAllWindows()
